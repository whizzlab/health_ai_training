# %%
import json

#from google.colab import files
#
#license_keys = files.upload()
#
#with open(list(license_keys.keys())[0]) as f:
#    license_keys = json.load(f)

with open('spark_license.json', 'r') as license:
    license_keys = json.load(license)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('You are using a low-RAM runtime!')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 37.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# %%capture
for k,v in license_keys.items(): 
    # %set_env $k=$v

# !wget https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/jsl_colab_setup.sh
# !bash jsl_colab_setup.sh

! pip install spark-nlp-display

# for Spark 2.4.x and Spark NLP 2.x, do the following
# !wget -q https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp-workshop/master/colab_setup.sh
# !bash colab_setup.sh -p 2.4.x -s 2.7.x

# %%
# if you want to start the session with custom params as in start function above
def start(secret):
    builder = SparkSession.builder \
        .appName("Spark NLP Licensed") \
        .master("local[*]") \
        .config("spark.driver.memory", "32G") \
        .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
        .config("spark.kryoserializer.buffer.max", "2000M") \
        .config("spark.jars.packages", "com.johnsnowlabs.nlp:spark-nlp_2.12:"+version) \
        .config("spark.jars", "https://pypi.johnsnowlabs.com/"+secret+"/spark-nlp-jsl-"+jsl_version+".jar")
      
    return builder.getOrCreate()

#spark = start(secret)

# %%
import json
import os
from pyspark.ml import Pipeline,PipelineModel
from pyspark.sql import SparkSession

from sparknlp.annotator import *
from sparknlp_jsl.annotator import *
from sparknlp.base import *
import sparknlp_jsl
import sparknlp

params = {"spark.driver.memory":"32G",
"spark.kryoserializer.buffer.max":"2000M",
"spark.driver.maxResultSize":"2000M"}

spark = sparknlp_jsl.start(license_keys['SECRET'],params=params)

print ("Spark NLP Version :", sparknlp.version())
print ("Spark NLP_JSL Version :", sparknlp_jsl.version())
# Out:
# Spark NLP Version : 3.1.0
# Spark NLP_JSL Version : 3.1.1

# %% [markdown]
# **PRETRAINED PIPELINE FOR CLINICAL NER**

# %%
# Annotator that transforms a text column from dataframe into an Annotation ready for NLP
documentAssembler = DocumentAssembler()\
        .setInputCol("text")\
        .setOutputCol("document")

# Sentence Detector annotator, processes various sentences per line

#sentenceDetector = SentenceDetector()\
        #.setInputCols(["document"])\
        #.setOutputCol("sentence")
sentenceDetector = SentenceDetectorDLModel.pretrained("sentence_detector_dl_healthcare","en","clinical/models")\
        .setInputCols(["document"])\
        .setOutputCol("sentence")
 
# Tokenizer splits words in a relevant format for NLP
tokenizer = Tokenizer()\
        .setInputCols(["sentence"])\
        .setOutputCol("token")

# Clinical word embeddings trained on PubMED dataset
word_embeddings = WordEmbeddingsModel.pretrained("embeddings_clinical","en","clinical/models")\
        .setInputCols(["sentence","token"])\
        .setOutputCol("embeddings")

# NER model trained on i2b2 (sampled from MIMIC) dataset
clinical_ner = MedicalNerModel.pretrained("ner_clinical_large","en","clinical/models")\
        .setInputCols(["sentence","token","embeddings"])\
        .setOutputCol("ner")

ner_converter = NerConverter()\
        .setInputCols(["sentence","token","ner"])\
        .setOutputCol("ner_chunk")

nlpPipeline = Pipeline(stages=[
        documentAssembler,
        sentenceDetector,
        tokenizer,
        word_embeddings,
        clinical_ner,
        ner_converter])


empty_data = spark.createDataFrame([[""]]).toDF("text")

model = nlpPipeline.fit(empty_data)
# Out:
# sentence_detector_dl_healthcare download started this may take some time.
# Approximate size to download 363.9 KB
# [OK!]
# embeddings_clinical download started this may take some time.
# Approximate size to download 1.6 GB
# [OK!]
# ner_clinical_large download started this may take some time.
# Approximate size to download 13.9 MB
# [OK!]

# %%
model.stages
# Out:
# [DocumentAssembler_df8a03e8df92,
#  SentenceDetectorDLModel_d2546f0acfe2,
#  REGEX_TOKENIZER_a2331202159d,
#  WORD_EMBEDDINGS_MODEL_9004b1d00302,
#  MedicalNerModel_1a8637089929,
#  NerConverter_96e0534b6ee9]

# %%
clinical_ner.getClasses()
# Out:
# ['O',
#  'B-TREATMENT',
#  'I-TREATMENT',
#  'B-PROBLEM',
#  'I-PROBLEM',
#  'B-TEST',
#  'I-TEST']

# %%
clinical_ner.extractParamMap()
# Out:
# {Param(parent='MedicalNerModel_1a8637089929', name='batchSize', doc='Size of every batch'): 64,
#  Param(parent='MedicalNerModel_1a8637089929', name='classes', doc='get the tags used to trained this MedicalNerModel'): ['O',
#   'B-TREATMENT',
#   'I-TREATMENT',
#   'B-PROBLEM',
#   'I-PROBLEM',
#   'B-TEST',
#   'I-TEST'],
#  Param(parent='MedicalNerModel_1a8637089929', name='includeAllConfidenceScores', doc='whether to include all confidence scores in annotation metadata or just the score of the predicted tag'): False,
#  Param(parent='MedicalNerModel_1a8637089929', name='includeConfidence', doc='whether to include confidence scores in annotation metadata'): True,
#  Param(parent='MedicalNerModel_1a8637089929', name='inferenceBatchSize', doc='number of sentences to process in a single batch during inference'): 1,
#  Param(parent='MedicalNerModel_1a8637089929', name='inputCols', doc='previous annotations columns, if renamed'): ['sentence',
#   'token',
#   'embeddings'],
#  Param(parent='MedicalNerModel_1a8637089929', name='lazyAnnotator', doc='Whether this AnnotatorModel acts as lazy in RecursivePipelines'): False,
#  Param(parent='MedicalNerModel_1a8637089929', name='outputCol', doc='output annotation column. can be left default.'): 'ner',
#  Param(parent='MedicalNerModel_1a8637089929', name='storageRef', doc='unique reference name for identification'): 'clinical'}

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5dcd5b26-e43e-4f0a-958b-8d7493abe91d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5dcd5b26-e43e-4f0a-958b-8d7493abe91d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all_text.csv to all_text.csv

# %%
import pyspark.sql.functions as F

pubMedDF = spark.read\
                .option("header", "true")\
                .csv("all_text.csv")\
                
pubMedDF.show(truncate=80)
# Out:
# +-----+--------------------------------------------------------------------------------+
# |index|                                                                            text|
# +-----+--------------------------------------------------------------------------------+
# |    0|Diagnostic accuracy of a novel artificial intelligence system for adenoma det...|
# |    2|Synthetic pulmonary perfusion images from 4DCT for functional avoidance using...|
# |    3|Prediction of chemotherapy response in breast cancer patients at pre-treatmen...|
# |    9|Deep learning for sex classification in resting-state and task functional bra...|
# |   15|Individualized Glaucoma Change Detection Using Deep Learning Auto Encoder-Bas...|
# |   20|A machine learning analysis of risk and protective factors of suicidal though...|
# |   24|Using Deep Learning Segmentation for Endotracheal Tube Position Assessment. T...|
# |   37|Automated detection and segmentation of sclerotic spinal lesions on body CTs ...|
# |   39|Dynamic Routing Capsule Networks for Mild Cognitive Impairment Diagnosis. Alz...|
# |   43|Early Prediction of Mortality, Severity, and Length of Stay in the Intensive ...|
# |   44|An Optimization Algorithm for Computer-Aided Diagnosis of Breast Cancer Based...|
# |   47|DeepCUBIT: Predicting Lymphovascular Invasion or Pathological Lymph Node Invo...|
# |   49|An immune-based risk-stratification system for predicting prognosis in pulmon...|
# |   53|Using Machine Learning to Characterize Atrial Fibrotic Substrate From Intraca...|
# |   54|HADLN: Hybrid Attention-Based Deep Learning Network for Automated Arrhythmia ...|
# |   56|Thalamus Radiomics-Based Disease Identification and Prediction of Early Treat...|
# |   58|Automated cortical thickness measurement of the mandibular condyle head on CB...|
# |   59|Machine learning-based preoperative datamining can predict the therapeutic ou...|
# |   62|Integrating ensemble systems biology feature selection and bimodal deep neura...|
# |   63|Characterizing intra-tumor regions on quantitative ultrasound parametric imag...|
# +-----+--------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
pubMedDF.tail(5)
# Out:
# [Row(index='161510', text='On the use of neural network techniques to analyze sleep EEG data. Third communication: robustification of the classificator by applying an algorithm obtained from 9 different networks. This is the third communication on the use of neural network techniques to classify sleep stages. In our first communication we presented the algorithms and the selection of the feature space and its reduction by using evolutionary and genetic procedures. In our second communication we trained the evolutionary optimized networks on the basis of multiple subject data in context with some smoothing algorithms in analogy of Rechtschaffen and Kales (RK). In this third communication we could demonstrate that the robustness concerning individual specific features of automatically generated sleep profiles could be reasonably improved by an additional modification of the procedure used by SASCIA (Sleep Analysis System to Challenge Innovative Artificial Networks). The outputs of nine different networks that were created by the data of 9 different subjects were used simultaneously for classification. The medians of the values obtained in each output measure were selected for the allocation to a sleep stage. The fitness criteria of 16 automatically generated sleep profiles showed reasonable concordance with the expert profile. Even though in single cases the concordance between conventional RK classifications and automatically generated profiles were a few percentages lower, the average correct classification of the 12 classified subjects improved substantially, thus proving that the classifier is more robust against individuum-specific variability. Despite the fact that the expert generally employs three channels (EEG, EMG and EOG), at least to build up sleep profiles, the SASCIA system was able to produce profiles on the basis of only one EEG channel with 80% concordance and a correlation coefficient of 0.86. The feature selections were performed by genetic algorithms and the topologies of the networks were optimized by evolutionary algorithms. This algorithm will now be used for larger sample forward classification.'),
#  Row(index='161511', text='Analysis of quantitative EEG with artificial neural networks and discriminant analysis--a methodological comparison. Artificial neural networks (ANN) are widely used to solve problems of differentiating between groups. However, serious comparisons of this method with the traditional procedure for such tasks (discriminant analysis) are rare. Discussing the results of both methods with the example of highly topical data, we try to demonstrate advantages and drawbacks of both methods. For this purpose, quantitative EEGs of 78 alcoholics were investigated in order to determine whether it is possible to predict relapse of these patients at the beginning of treatment. ANN software is available in Kassel (Institute for Computer Sciences and Mathematics).'),
#  Row(index='161513', text='"Neural networks as a prognostic tool for patients with non-small cell carcinoma of the lung. Patients with non-small cell carcinoma of the lung (NSCLC) have a poor prognosis (64 and 41% survival rates in Stages I and II). It is currently not possible to predict which patients with Stage I or II NSCLC will survive the disease. Sixty-seven patients with NSCLC, including 49 patients with Stage I NSCLC and 18 with Stage II disease (11 with squamous cell carcinomas, 35 with adenocarcinomas, and 21 with large cell carcinomas) were treated with lobectomy and followed for a minimum of 5 years. The tumors were studied with DNA flow cytometry and quantitative immunocytochemical studies for proliferation cell nuclear antigen, p53 protein, and MIB-1. The data were analyzed with backpropagation neural networks, univariate analysis of variance, the Kaplan-Meier survival method, and Cox proportional hazards model. The dependent variables were ""free of disease"" and ""recurrence or dead from disease."" Twenty neural network models were trained'),
#  Row(index='161517', text="Automated interpretation of myocardial SPECT perfusion images using artificial neural networks. The purpose of this study was to develop a computer-based method for automatic detection and localization of coronary artery disease (CAD) in myocardial bull's-eye scintigrams."),
#  Row(index='161524', text='Acute pulmonary embolism: cost-effectiveness analysis of the effect of artificial neural networks on patient care. To evaluate the cost-effectiveness of artificial neural networks for diagnosis in patients suspected of having acute pulmonary embolism who are typically referred for pulmonary angiography.')]

# %%
result = model.transform(pubMedDF)
result.show(truncate=80)
# Out:
# +-----+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+
# |index|                                                                            text|                                                                        document|                                                                        sentence|                                                                           token|                                                                      embeddings|                                                                             ner|                                                                       ner_chunk|
# +-----+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+
# |    0|Diagnostic accuracy of a novel artificial intelligence system for adenoma det...|[{document, 0, 477, Diagnostic accuracy of a novel artificial intelligence sy...|[{document, 0, 149, Diagnostic accuracy of a novel artificial intelligence sy...|[{token, 0, 9, Diagnostic, {sentence -> 0}, []}, {token, 11, 18, accuracy, {s...|[{word_embeddings, 0, 9, Diagnostic, {isOOV -> false, pieceId -> -1, isWordSt...|[{named_entity, 0, 9, O, {word -> Diagnostic, confidence -> 0.9866}, []}, {na...|[{chunk, 23, 60, a novel artificial intelligence system, {entity -> TREATMENT...|
# |    2|Synthetic pulmonary perfusion images from 4DCT for functional avoidance using...|[{document, 0, 285, Synthetic pulmonary perfusion images from 4DCT for functi...|[{document, 0, 91, Synthetic pulmonary perfusion images from 4DCT for functio...|[{token, 0, 8, Synthetic, {sentence -> 0}, []}, {token, 10, 18, pulmonary, {s...|[{word_embeddings, 0, 8, Synthetic, {isOOV -> false, pieceId -> -1, isWordSta...|[{named_entity, 0, 8, B-PROBLEM, {word -> Synthetic, confidence -> 0.8553}, [...|[{chunk, 0, 35, Synthetic pulmonary perfusion images, {entity -> PROBLEM, sen...|
# |    3|Prediction of chemotherapy response in breast cancer patients at pre-treatmen...|[{document, 0, 1735, Prediction of chemotherapy response in breast cancer pat...|[{document, 0, 144, Prediction of chemotherapy response in breast cancer pati...|[{token, 0, 9, Prediction, {sentence -> 0}, []}, {token, 11, 12, of, {sentenc...|[{word_embeddings, 0, 9, Prediction, {isOOV -> false, pieceId -> -1, isWordSt...|[{named_entity, 0, 9, O, {word -> Prediction, confidence -> 0.3682}, []}, {na...|[{chunk, 14, 34, chemotherapy response, {entity -> TREATMENT, sentence -> 0, ...|
# |    9|Deep learning for sex classification in resting-state and task functional bra...|[{document, 0, 1434, Deep learning for sex classification in resting-state an...|[{document, 0, 108, Deep learning for sex classification in resting-state and...|[{token, 0, 3, Deep, {sentence -> 0}, []}, {token, 5, 12, learning, {sentence...|[{word_embeddings, 0, 3, Deep, {isOOV -> false, pieceId -> -1, isWordStart ->...|[{named_entity, 0, 3, O, {word -> Deep, confidence -> 0.948}, []}, {named_ent...|[{chunk, 128, 171, whole-brain functional connectivity MRI data, {entity -> T...|
# |   15|Individualized Glaucoma Change Detection Using Deep Learning Auto Encoder-Bas...|[{document, 0, 402, Individualized Glaucoma Change Detection Using Deep Learn...|[{document, 0, 402, Individualized Glaucoma Change Detection Using Deep Learn...|[{token, 0, 13, Individualized, {sentence -> 0}, []}, {token, 15, 22, Glaucom...|[{word_embeddings, 0, 13, Individualized, {isOOV -> false, pieceId -> -1, isW...|[{named_entity, 0, 13, O, {word -> Individualized, confidence -> 0.7262}, []}...|[{chunk, 15, 39, Glaucoma Change Detection, {entity -> PROBLEM, sentence -> 0...|
# |   20|A machine learning analysis of risk and protective factors of suicidal though...|[{document, 0, 233, A machine learning analysis of risk and protective factor...|[{document, 0, 113, A machine learning analysis of risk and protective factor...|[{token, 0, 0, A, {sentence -> 0}, []}, {token, 2, 8, machine, {sentence -> 0...|[{word_embeddings, 0, 0, A, {isOOV -> false, pieceId -> -1, isWordStart -> tr...|[{named_entity, 0, 0, B-TEST, {word -> A, confidence -> 0.4542}, []}, {named_...|[{chunk, 0, 26, A machine learning analysis, {entity -> TEST, sentence -> 0, ...|
# |   24|Using Deep Learning Segmentation for Endotracheal Tube Position Assessment. T...|[{document, 0, 235, Using Deep Learning Segmentation for Endotracheal Tube Po...|[{document, 0, 74, Using Deep Learning Segmentation for Endotracheal Tube Pos...|[{token, 0, 4, Using, {sentence -> 0}, []}, {token, 6, 9, Deep, {sentence -> ...|[{word_embeddings, 0, 4, Using, {isOOV -> false, pieceId -> -1, isWordStart -...|[{named_entity, 0, 4, O, {word -> Using, confidence -> 0.9993}, []}, {named_e...|[{chunk, 6, 31, Deep Learning Segmentation, {entity -> TEST, sentence -> 0, c...|
# |   37|Automated detection and segmentation of sclerotic spinal lesions on body CTs ...|[{document, 0, 227, Automated detection and segmentation of sclerotic spinal ...|[{document, 0, 118, Automated detection and segmentation of sclerotic spinal ...|[{token, 0, 8, Automated, {sentence -> 0}, []}, {token, 10, 18, detection, {s...|[{word_embeddings, 0, 8, Automated, {isOOV -> false, pieceId -> -1, isWordSta...|[{named_entity, 0, 8, B-TEST, {word -> Automated, confidence -> 0.7888}, []},...|[{chunk, 0, 18, Automated detection, {entity -> TEST, sentence -> 0, chunk ->...|
# |   39|Dynamic Routing Capsule Networks for Mild Cognitive Impairment Diagnosis. Alz...|[{document, 0, 1532, Dynamic Routing Capsule Networks for Mild Cognitive Impa...|[{document, 0, 72, Dynamic Routing Capsule Networks for Mild Cognitive Impair...|[{token, 0, 6, Dynamic, {sentence -> 0}, []}, {token, 8, 14, Routing, {senten...|[{word_embeddings, 0, 6, Dynamic, {isOOV -> false, pieceId -> -1, isWordStart...|[{named_entity, 0, 6, B-TREATMENT, {word -> Dynamic, confidence -> 0.587}, []...|[{chunk, 0, 31, Dynamic Routing Capsule Networks, {entity -> TREATMENT, sente...|
# |   43|Early Prediction of Mortality, Severity, and Length of Stay in the Intensive ...|[{document, 0, 1850, Early Prediction of Mortality, Severity, and Length of S...|[{document, 0, 152, Early Prediction of Mortality, Severity, and Length of St...|[{token, 0, 4, Early, {sentence -> 0}, []}, {token, 6, 15, Prediction, {sente...|[{word_embeddings, 0, 4, Early, {isOOV -> false, pieceId -> -1, isWordStart -...|[{named_entity, 0, 4, O, {word -> Early, confidence -> 0.9899}, []}, {named_e...|[{chunk, 90, 95, Sepsis, {entity -> PROBLEM, sentence -> 0, chunk -> 0}, []},...|
# |   44|An Optimization Algorithm for Computer-Aided Diagnosis of Breast Cancer Based...|[{document, 0, 1479, An Optimization Algorithm for Computer-Aided Diagnosis o...|[{document, 0, 103, An Optimization Algorithm for Computer-Aided Diagnosis of...|[{token, 0, 1, An, {sentence -> 0}, []}, {token, 3, 14, Optimization, {senten...|[{word_embeddings, 0, 1, An, {isOOV -> false, pieceId -> -1, isWordStart -> t...|[{named_entity, 0, 1, B-TREATMENT, {word -> An, confidence -> 0.5228}, []}, {...|[{chunk, 0, 24, An Optimization Algorithm, {entity -> TREATMENT, sentence -> ...|
# |   47|DeepCUBIT: Predicting Lymphovascular Invasion or Pathological Lymph Node Invo...|[{document, 0, 1847, DeepCUBIT: Predicting Lymphovascular Invasion or Patholo...|[{document, 0, 203, DeepCUBIT: Predicting Lymphovascular Invasion or Patholog...|[{token, 0, 8, DeepCUBIT, {sentence -> 0}, []}, {token, 9, 9, :, {sentence ->...|[{word_embeddings, 0, 8, DeepCUBIT, {isOOV -> true, pieceId -> -1, isWordStar...|[{named_entity, 0, 8, O, {word -> DeepCUBIT, confidence -> 0.764}, []}, {name...|[{chunk, 22, 44, Lymphovascular Invasion, {entity -> PROBLEM, sentence -> 0, ...|
# |   49|An immune-based risk-stratification system for predicting prognosis in pulmon...|[{document, 0, 2192, An immune-based risk-stratification system for predictin...|[{document, 0, 108, An immune-based risk-stratification system for predicting...|[{token, 0, 1, An, {sentence -> 0}, []}, {token, 3, 14, immune-based, {senten...|[{word_embeddings, 0, 1, An, {isOOV -> false, pieceId -> -1, isWordStart -> t...|[{named_entity, 0, 1, B-TEST, {word -> An, confidence -> 0.7887}, []}, {named...|[{chunk, 0, 41, An immune-based risk-stratification system, {entity -> TEST, ...|
# |   53|Using Machine Learning to Characterize Atrial Fibrotic Substrate From Intraca...|[{document, 0, 1595, Using Machine Learning to Characterize Atrial Fibrotic S...|[{document, 0, 148, Using Machine Learning to Characterize Atrial Fibrotic Su...|[{token, 0, 4, Using, {sentence -> 0}, []}, {token, 6, 12, Machine, {sentence...|[{word_embeddings, 0, 4, Using, {isOOV -> false, pieceId -> -1, isWordStart -...|[{named_entity, 0, 4, O, {word -> Using, confidence -> 0.9946}, []}, {named_e...|[{chunk, 70, 89, Intracardiac Signals, {entity -> TEST, sentence -> 0, chunk ...|
# |   54|HADLN: Hybrid Attention-Based Deep Learning Network for Automated Arrhythmia ...|[{document, 0, 1401, HADLN: Hybrid Attention-Based Deep Learning Network for ...|[{document, 0, 91, HADLN: Hybrid Attention-Based Deep Learning Network for Au...|[{token, 0, 4, HADLN, {sentence -> 0}, []}, {token, 5, 5, :, {sentence -> 0},...|[{word_embeddings, 0, 4, HADLN, {isOOV -> true, pieceId -> -1, isWordStart ->...|[{named_entity, 0, 4, O, {word -> HADLN, confidence -> 0.9494}, []}, {named_e...|[{chunk, 56, 90, Automated Arrhythmia Classification, {entity -> PROBLEM, sen...|
# |   56|Thalamus Radiomics-Based Disease Identification and Prediction of Early Treat...|[{document, 0, 625, Thalamus Radiomics-Based Disease Identification and Predi...|[{document, 0, 108, Thalamus Radiomics-Based Disease Identification and Predi...|[{token, 0, 7, Thalamus, {sentence -> 0}, []}, {token, 9, 23, Radiomics-Based...|[{word_embeddings, 0, 7, Thalamus, {isOOV -> false, pieceId -> -1, isWordStar...|[{named_entity, 0, 7, B-PROBLEM, {word -> Thalamus, confidence -> 0.5941}, []...|[{chunk, 0, 46, Thalamus Radiomics-Based Disease Identification, {entity -> P...|
# |   58|Automated cortical thickness measurement of the mandibular condyle head on CB...|[{document, 0, 1457, Automated cortical thickness measurement of the mandibul...|[{document, 0, 115, Automated cortical thickness measurement of the mandibula...|[{token, 0, 8, Automated, {sentence -> 0}, []}, {token, 10, 17, cortical, {se...|[{word_embeddings, 0, 8, Automated, {isOOV -> false, pieceId -> -1, isWordSta...|[{named_entity, 0, 8, O, {word -> Automated, confidence -> 0.7317}, []}, {nam...|[{chunk, 75, 85, CBCT images, {entity -> TEST, sentence -> 0, chunk -> 0}, []...|
# |   59|Machine learning-based preoperative datamining can predict the therapeutic ou...|[{document, 0, 1544, Machine learning-based preoperative datamining can predi...|[{document, 0, 115, Machine learning-based preoperative datamining can predic...|[{token, 0, 6, Machine, {sentence -> 0}, []}, {token, 8, 21, learning-based, ...|[{word_embeddings, 0, 6, Machine, {isOOV -> false, pieceId -> -1, isWordStart...|[{named_entity, 0, 6, B-TREATMENT, {word -> Machine, confidence -> 0.6503}, [...|[{chunk, 0, 45, Machine learning-based preoperative datamining, {entity -> TR...|
# |   62|Integrating ensemble systems biology feature selection and bimodal deep neura...|[{document, 0, 1525, Integrating ensemble systems biology feature selection a...|[{document, 0, 125, Integrating ensemble systems biology feature selection an...|[{token, 0, 10, Integrating, {sentence -> 0}, []}, {token, 12, 19, ensemble, ...|[{word_embeddings, 0, 10, Integrating, {isOOV -> false, pieceId -> -1, isWord...|[{named_entity, 0, 10, O, {word -> Integrating, confidence -> 0.9617}, []}, {...|[{chunk, 91, 103, breast cancer, {entity -> PROBLEM, sentence -> 0, chunk -> ...|
# |   63|Characterizing intra-tumor regions on quantitative ultrasound parametric imag...|[{document, 0, 2454, Characterizing intra-tumor regions on quantitative ultra...|[{document, 0, 146, Characterizing intra-tumor regions on quantitative ultras...|[{token, 0, 13, Characterizing, {sentence -> 0}, []}, {token, 15, 25, intra-t...|[{word_embeddings, 0, 13, Characterizing, {isOOV -> false, pieceId -> -1, isW...|[{named_entity, 0, 13, O, {word -> Characterizing, confidence -> 0.877}, []},...|[{chunk, 38, 78, quantitative ultrasound parametric images, {entity -> TEST, ...|
# +-----+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+--------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
result.tail(5)
# Out:
# [Row(index='161510', text='On the use of neural network techniques to analyze sleep EEG data. Third communication: robustification of the classificator by applying an algorithm obtained from 9 different networks. This is the third communication on the use of neural network techniques to classify sleep stages. In our first communication we presented the algorithms and the selection of the feature space and its reduction by using evolutionary and genetic procedures. In our second communication we trained the evolutionary optimized networks on the basis of multiple subject data in context with some smoothing algorithms in analogy of Rechtschaffen and Kales (RK). In this third communication we could demonstrate that the robustness concerning individual specific features of automatically generated sleep profiles could be reasonably improved by an additional modification of the procedure used by SASCIA (Sleep Analysis System to Challenge Innovative Artificial Networks). The outputs of nine different networks that were created by the data of 9 different subjects were used simultaneously for classification. The medians of the values obtained in each output measure were selected for the allocation to a sleep stage. The fitness criteria of 16 automatically generated sleep profiles showed reasonable concordance with the expert profile. Even though in single cases the concordance between conventional RK classifications and automatically generated profiles were a few percentages lower, the average correct classification of the 12 classified subjects improved substantially, thus proving that the classifier is more robust against individuum-specific variability. Despite the fact that the expert generally employs three channels (EEG, EMG and EOG), at least to build up sleep profiles, the SASCIA system was able to produce profiles on the basis of only one EEG channel with 80% concordance and a correlation coefficient of 0.86. The feature selections were performed by genetic algorithms and the topologies of the networks were optimized by evolutionary algorithms. This algorithm will now be used for larger sample forward classification.', document=[Row(annotatorType='document', begin=0, end=2126, result='On the use of neural network techniques to analyze sleep EEG data. Third communication: robustification of the classificator by applying an algorithm obtained from 9 different networks. This is the third communication on the use of neural network techniques to classify sleep stages. In our first communication we presented the algorithms and the selection of the feature space and its reduction by using evolutionary and genetic procedures. In our second communication we trained the evolutionary optimized networks on the basis of multiple subject data in context with some smoothing algorithms in analogy of Rechtschaffen and Kales (RK). In this third communication we could demonstrate that the robustness concerning individual specific features of automatically generated sleep profiles could be reasonably improved by an additional modification of the procedure used by SASCIA (Sleep Analysis System to Challenge Innovative Artificial Networks). The outputs of nine different networks that were created by the data of 9 different subjects were used simultaneously for classification. The medians of the values obtained in each output measure were selected for the allocation to a sleep stage. The fitness criteria of 16 automatically generated sleep profiles showed reasonable concordance with the expert profile. Even though in single cases the concordance between conventional RK classifications and automatically generated profiles were a few percentages lower, the average correct classification of the 12 classified subjects improved substantially, thus proving that the classifier is more robust against individuum-specific variability. Despite the fact that the expert generally employs three channels (EEG, EMG and EOG), at least to build up sleep profiles, the  ...
#  Row(index='161511', text='Analysis of quantitative EEG with artificial neural networks and discriminant analysis--a methodological comparison. Artificial neural networks (ANN) are widely used to solve problems of differentiating between groups. However, serious comparisons of this method with the traditional procedure for such tasks (discriminant analysis) are rare. Discussing the results of both methods with the example of highly topical data, we try to demonstrate advantages and drawbacks of both methods. For this purpose, quantitative EEGs of 78 alcoholics were investigated in order to determine whether it is possible to predict relapse of these patients at the beginning of treatment. ANN software is available in Kassel (Institute for Computer Sciences and Mathematics).', document=[Row(annotatorType='document', begin=0, end=756, result='Analysis of quantitative EEG with artificial neural networks and discriminant analysis--a methodological comparison. Artificial neural networks (ANN) are widely used to solve problems of differentiating between groups. However, serious comparisons of this method with the traditional procedure for such tasks (discriminant analysis) are rare. Discussing the results of both methods with the example of highly topical data, we try to demonstrate advantages and drawbacks of both methods. For this purpose, quantitative EEGs of 78 alcoholics were investigated in order to determine whether it is possible to predict relapse of these patients at the beginning of treatment. ANN software is available in Kassel (Institute for Computer Sciences and Mathematics).', metadata={'sentence': '0'}, embeddings=[])], sentence=[Row(annotatorType='document', begin=0, end=115, result='Analysis of quantitative EEG with artificial neural networks and discriminant analysis--a methodological comparison.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='document', begin=117, end=217, result='Artificial neural networks (ANN) are widely used to solve problems of differentiating between groups.', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='document', begin=219, end=341, result='However, serious comparisons of this method with the traditional procedure for such tasks (discriminant analysis) are rare.', metadata={'sentence': '2'}, embeddings=[]), Row(annotatorType='document', begin=343, end=485, result='Discussing the results of both methods with the example of highly topical data, we try to demonstrate advantages and drawbacks of both methods.', metadata={'sentence': '3'}, embeddings=[]), Row(annotatorType='document', begin=487, end=669, result='For this purpose, quantitative EEGs of 78 alcoholics were investigated in order to determine whether it is possible to predict relapse of these patients at the beginning of treatment.', metadata={'sentence': '4'}, embeddings=[]), Row(annotatorType='document', begin=671, end=756, result='ANN software is available in Kassel (Institute for Computer Sciences and Mathematics).', metadata={'sentence': '5'}, embeddings=[])], token=[Row(annotatorType='token', begin=0, end=7, result='Analysis', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=9, end=10, result='of', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=12, end=23, result='quantitative', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=25, end=27, result='EEG', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=29, end=32, result='with', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=34, end=43, result='artificial', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=45, end=50, result='neural', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=52, end=59, result='networks', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=61, end=63, result='and', metadata={'sentence': '0'}, embeddi ...
#  Row(index='161513', text='"Neural networks as a prognostic tool for patients with non-small cell carcinoma of the lung. Patients with non-small cell carcinoma of the lung (NSCLC) have a poor prognosis (64 and 41% survival rates in Stages I and II). It is currently not possible to predict which patients with Stage I or II NSCLC will survive the disease. Sixty-seven patients with NSCLC, including 49 patients with Stage I NSCLC and 18 with Stage II disease (11 with squamous cell carcinomas, 35 with adenocarcinomas, and 21 with large cell carcinomas) were treated with lobectomy and followed for a minimum of 5 years. The tumors were studied with DNA flow cytometry and quantitative immunocytochemical studies for proliferation cell nuclear antigen, p53 protein, and MIB-1. The data were analyzed with backpropagation neural networks, univariate analysis of variance, the Kaplan-Meier survival method, and Cox proportional hazards model. The dependent variables were ""free of disease"" and ""recurrence or dead from disease."" Twenty neural network models were trained', document=[Row(annotatorType='document', begin=0, end=1044, result='"Neural networks as a prognostic tool for patients with non-small cell carcinoma of the lung. Patients with non-small cell carcinoma of the lung (NSCLC) have a poor prognosis (64 and 41% survival rates in Stages I and II). It is currently not possible to predict which patients with Stage I or II NSCLC will survive the disease. Sixty-seven patients with NSCLC, including 49 patients with Stage I NSCLC and 18 with Stage II disease (11 with squamous cell carcinomas, 35 with adenocarcinomas, and 21 with large cell carcinomas) were treated with lobectomy and followed for a minimum of 5 years. The tumors were studied with DNA flow cytometry and quantitative immunocytochemical studies for proliferation cell nuclear antigen, p53 protein, and MIB-1. The data were analyzed with backpropagation neural networks, univariate analysis of variance, the Kaplan-Meier survival method, and Cox proportional hazards model. The dependent variables were ""free of disease"" and ""recurrence or dead from disease."" Twenty neural network models were trained', metadata={'sentence': '0'}, embeddings=[])], sentence=[Row(annotatorType='document', begin=0, end=92, result='"Neural networks as a prognostic tool for patients with non-small cell carcinoma of the lung.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='document', begin=94, end=221, result='Patients with non-small cell carcinoma of the lung (NSCLC) have a poor prognosis (64 and 41% survival rates in Stages I and II).', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='document', begin=223, end=327, result='It is currently not possible to predict which patients with Stage I or II NSCLC will survive the disease.', metadata={'sentence': '2'}, embeddings=[]), Row(annotatorType='document', begin=329, end=592, result='Sixty-seven patients with NSCLC, including 49 patients with Stage I NSCLC and 18 with Stage II disease (11 with squamous cell carcinomas, 35 with adenocarcinomas, and 21 with large cell carcinomas) were treated with lobectomy and followed for a minimum of 5 years.', metadata={'sentence': '3'}, embeddings=[]), Row(annotatorType='document', begin=594, end=748, result='The tumors were studied with DNA flow cytometry and quantitative immunocytochemical studies for proliferation cell nuclear antigen, p53 protein, and MIB-1.', metadata={'sentence': '4'}, embeddings=[]), Row(annotatorType='document', begin=750, end=912, result='The data were analyzed with backpropagation neural networks, univariate analysis of variance, the Kaplan-Meier survival method, and Cox proportional hazards model.', metadata={'sentence': '5'}, embeddings=[]), Row(annotatorType='document', begin=914, end=1000, result='The dependent variables were ""free of disease"" and ""recurrence or dead from disease.', metadata={'sentence': '6'}, embeddings=[]), Row(annotatorType='document' ...
#  Row(index='161517', text="Automated interpretation of myocardial SPECT perfusion images using artificial neural networks. The purpose of this study was to develop a computer-based method for automatic detection and localization of coronary artery disease (CAD) in myocardial bull's-eye scintigrams.", document=[Row(annotatorType='document', begin=0, end=271, result="Automated interpretation of myocardial SPECT perfusion images using artificial neural networks. The purpose of this study was to develop a computer-based method for automatic detection and localization of coronary artery disease (CAD) in myocardial bull's-eye scintigrams.", metadata={'sentence': '0'}, embeddings=[])], sentence=[Row(annotatorType='document', begin=0, end=94, result='Automated interpretation of myocardial SPECT perfusion images using artificial neural networks.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='document', begin=96, end=271, result="The purpose of this study was to develop a computer-based method for automatic detection and localization of coronary artery disease (CAD) in myocardial bull's-eye scintigrams.", metadata={'sentence': '1'}, embeddings=[])], token=[Row(annotatorType='token', begin=0, end=8, result='Automated', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=10, end=23, result='interpretation', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=25, end=26, result='of', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=28, end=37, result='myocardial', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=39, end=43, result='SPECT', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=45, end=53, result='perfusion', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=55, end=60, result='images', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=62, end=66, result='using', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=68, end=77, result='artificial', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=79, end=84, result='neural', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=86, end=93, result='networks', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=94, end=94, result='.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=96, end=98, result='The', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=100, end=106, result='purpose', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=108, end=109, result='of', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=111, end=114, result='this', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=116, end=120, result='study', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=122, end=124, result='was', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=126, end=127, result='to', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=129, end=135, result='develop', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=137, end=137, result='a', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=139, end=152, result='computer-based', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=154, end=159, result='method', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=161, end=163, result='for', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=165, end=173, result='automatic', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=175, end=183, result='detection', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin= ...
#  Row(index='161524', text='Acute pulmonary embolism: cost-effectiveness analysis of the effect of artificial neural networks on patient care. To evaluate the cost-effectiveness of artificial neural networks for diagnosis in patients suspected of having acute pulmonary embolism who are typically referred for pulmonary angiography.', document=[Row(annotatorType='document', begin=0, end=303, result='Acute pulmonary embolism: cost-effectiveness analysis of the effect of artificial neural networks on patient care. To evaluate the cost-effectiveness of artificial neural networks for diagnosis in patients suspected of having acute pulmonary embolism who are typically referred for pulmonary angiography.', metadata={'sentence': '0'}, embeddings=[])], sentence=[Row(annotatorType='document', begin=0, end=113, result='Acute pulmonary embolism: cost-effectiveness analysis of the effect of artificial neural networks on patient care.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='document', begin=115, end=303, result='To evaluate the cost-effectiveness of artificial neural networks for diagnosis in patients suspected of having acute pulmonary embolism who are typically referred for pulmonary angiography.', metadata={'sentence': '1'}, embeddings=[])], token=[Row(annotatorType='token', begin=0, end=4, result='Acute', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=6, end=14, result='pulmonary', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=16, end=23, result='embolism', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=24, end=24, result=':', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=26, end=43, result='cost-effectiveness', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=45, end=52, result='analysis', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=54, end=55, result='of', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=57, end=59, result='the', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=61, end=66, result='effect', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=68, end=69, result='of', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=71, end=80, result='artificial', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=82, end=87, result='neural', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=89, end=96, result='networks', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=98, end=99, result='on', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=101, end=107, result='patient', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=109, end=112, result='care', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=113, end=113, result='.', metadata={'sentence': '0'}, embeddings=[]), Row(annotatorType='token', begin=115, end=116, result='To', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=118, end=125, result='evaluate', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=127, end=129, result='the', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=131, end=148, result='cost-effectiveness', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=150, end=151, result='of', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=153, end=162, result='artificial', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=164, end=169, result='neural', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=171, end=178, result='networks', metadata={'sentence': '1'}, embeddings=[]), Row(annotatorType='token', begin=180, end=1 ...

# %%
# result.show(n = 1000, truncate = 50)

# %%
#uploaded = files.upload()

# %%
#index_df = spark.read.option("header", True) \
#  .csv("index.csv")

# %%
#from pyspark.sql.functions import col, split
#
#index_df = index_df.withColumn("index", split(col("index"), ",").cast("array<long>"))
#index_df.show()

# %%
#from pyspark.sql.window import Window
#from pyspark.sql.functions import monotonically_increasing_id, row_number
#
# since there is no common column between these two dataframes add row_index so that it can be joined
#temp1=index_df.withColumn('row_index', row_number().over(Window.orderBy(monotonically_increasing_id())))
#temp2=transformed.withColumn('row_index', row_number().over(Window.orderBy(monotonically_increasing_id())))
#
#result = temp1.join(temp2, on=["row_index"]).drop("row_index")
#result.show()

# %%
labelled = result.select('index','ner_chunk.result','ner_chunk.metadata')
labelled.show(n = 5, truncate=128)
# Out:
# +-----+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# |index|                                                                                                                          result|                                                                                                                        metadata|
# +-----+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# |    0|[a novel artificial intelligence system, adenoma, a prospective non-randomized comparative study, Adenoma detection rate (ADR...|[{entity -> TREATMENT, sentence -> 0, chunk -> 0}, {entity -> PROBLEM, sentence -> 0, chunk -> 1}, {entity -> TEST, sentence ...|
# |    2|   [Synthetic pulmonary perfusion images, functional avoidance, synthetic pulmonary perfusion images, radiotherapy, lung cancer]|[{entity -> PROBLEM, sentence -> 0, chunk -> 0}, {entity -> PROBLEM, sentence -> 0, chunk -> 1}, {entity -> PROBLEM, sentence...|
# |    3|[chemotherapy response, breast cancer, second derivative texture, CT images, neoadjuvant chemotherapy, treatment, locally adv...|[{entity -> TREATMENT, sentence -> 0, chunk -> 0}, {entity -> PROBLEM, sentence -> 0, chunk -> 1}, {entity -> TREATMENT, sent...|
# |    9|[whole-brain functional connectivity MRI data, encoding abstract input data, these techniques, a stochastic encoding method, ...|[{entity -> TEST, sentence -> 1, chunk -> 0}, {entity -> PROBLEM, sentence -> 2, chunk -> 1}, {entity -> TREATMENT, sentence ...|
# |   15|[Glaucoma Change Detection, Encoder-Based Regions of Interest, optical coherence tomography (OCT, retinal nerve fiber layer (...|[{entity -> PROBLEM, sentence -> 0, chunk -> 0}, {entity -> TREATMENT, sentence -> 0, chunk -> 1}, {entity -> TEST, sentence ...|
# +-----+--------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
labelled.tail(5)
# Out:
# [Row(index='161510', result=['neural network techniques', 'an algorithm', 'neural network techniques', 'the algorithms', 'its reduction', 'evolutionary', 'genetic procedures', 'some smoothing algorithms', 'an additional modification of the procedure', 'Innovative Artificial Networks', 'The outputs of nine different networks', 'the values', 'each output measure', 'individuum-specific variability', 'three channels', 'EEG', 'EMG', 'EOG', 'one EEG channel', 'The feature selections', 'genetic algorithms', 'evolutionary algorithms', 'This algorithm'], metadata=[{'sentence': '0', 'chunk': '0', 'entity': 'TREATMENT'}, {'sentence': '1', 'chunk': '1', 'entity': 'TEST'}, {'sentence': '2', 'chunk': '2', 'entity': 'TREATMENT'}, {'sentence': '3', 'chunk': '3', 'entity': 'TREATMENT'}, {'sentence': '3', 'chunk': '4', 'entity': 'TREATMENT'}, {'sentence': '3', 'chunk': '5', 'entity': 'TREATMENT'}, {'sentence': '3', 'chunk': '6', 'entity': 'TREATMENT'}, {'sentence': '4', 'chunk': '7', 'entity': 'TREATMENT'}, {'sentence': '5', 'chunk': '8', 'entity': 'TREATMENT'}, {'sentence': '5', 'chunk': '9', 'entity': 'TREATMENT'}, {'sentence': '6', 'chunk': '10', 'entity': 'TEST'}, {'sentence': '7', 'chunk': '11', 'entity': 'TEST'}, {'sentence': '7', 'chunk': '12', 'entity': 'TEST'}, {'sentence': '9', 'chunk': '13', 'entity': 'PROBLEM'}, {'sentence': '10', 'chunk': '14', 'entity': 'TEST'}, {'sentence': '10', 'chunk': '15', 'entity': 'TEST'}, {'sentence': '10', 'chunk': '16', 'entity': 'TEST'}, {'sentence': '10', 'chunk': '17', 'entity': 'TEST'}, {'sentence': '10', 'chunk': '18', 'entity': 'PROBLEM'}, {'sentence': '11', 'chunk': '19', 'entity': 'TREATMENT'}, {'sentence': '11', 'chunk': '20', 'entity': 'TREATMENT'}, {'sentence': '11', 'chunk': '21', 'entity': 'TREATMENT'}, {'sentence': '12', 'chunk': '22', 'entity': 'TREATMENT'}]),
#  Row(index='161511', result=['EEG', 'discriminant analysis--a', 'Artificial neural networks (ANN)', 'this method', 'the traditional procedure', 'discriminant analysis', 'highly topical data', 'quantitative EEGs', 'treatment'], metadata=[{'sentence': '0', 'chunk': '0', 'entity': 'TEST'}, {'sentence': '0', 'chunk': '1', 'entity': 'TEST'}, {'sentence': '1', 'chunk': '2', 'entity': 'TREATMENT'}, {'sentence': '2', 'chunk': '3', 'entity': 'TREATMENT'}, {'sentence': '2', 'chunk': '4', 'entity': 'TREATMENT'}, {'sentence': '2', 'chunk': '5', 'entity': 'TEST'}, {'sentence': '3', 'chunk': '6', 'entity': 'TREATMENT'}, {'sentence': '4', 'chunk': '7', 'entity': 'TEST'}, {'sentence': '4', 'chunk': '8', 'entity': 'TREATMENT'}]),
#  Row(index='161513', result=['non-small cell carcinoma of the lung', 'non-small cell carcinoma of the lung', 'Stage I or II NSCLC', 'the disease', 'NSCLC', 'Stage I NSCLC', 'Stage II disease', 'squamous cell carcinomas', 'adenocarcinomas', 'large cell carcinomas', 'lobectomy', 'The tumors', 'DNA flow cytometry', 'proliferation cell nuclear antigen', 'p53 protein', 'MIB-1', 'the Kaplan-Meier survival method', 'The dependent variables', 'disease', 'recurrence', 'dead from disease'], metadata=[{'sentence': '0', 'chunk': '0', 'entity': 'PROBLEM'}, {'sentence': '1', 'chunk': '1', 'entity': 'PROBLEM'}, {'sentence': '2', 'chunk': '2', 'entity': 'TREATMENT'}, {'sentence': '2', 'chunk': '3', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '4', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '5', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '6', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '7', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '8', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '9', 'entity': 'PROBLEM'}, {'sentence': '3', 'chunk': '10', 'entity': 'TREATMENT'}, {'sentence': '4', 'chunk': '11', 'entity': 'PROBLEM'}, {'sentence': '4', 'chunk': '12', 'entity': 'TEST'}, {'sentence': '4', 'chunk': '13', 'entity': 'TEST'}, {'sentence': '4', 'chunk': '14', 'entity': 'TEST'}, {'sentence': '4', 'chunk': '15', 'entity': 'TEST'}, {'sentence': '5', 'chunk': '16', 'entity': 'TREATMENT'}, {'sentence': '6', 'chunk': '17', 'entity': 'PROBLEM'}, {'sentence': '6', 'chunk': '18', 'entity': 'PROBLEM'}, {'sentence': '6', 'chunk': '19', 'entity': 'PROBLEM'}, {'sentence': '6', 'chunk': '20', 'entity': 'PROBLEM'}]),
#  Row(index='161517', result=['myocardial SPECT perfusion images', 'artificial neural networks', 'this study', 'a computer-based method', 'coronary artery disease', 'CAD', "myocardial bull's-eye scintigrams"], metadata=[{'sentence': '0', 'chunk': '0', 'entity': 'TEST'}, {'sentence': '0', 'chunk': '1', 'entity': 'TREATMENT'}, {'sentence': '1', 'chunk': '2', 'entity': 'TEST'}, {'sentence': '1', 'chunk': '3', 'entity': 'TREATMENT'}, {'sentence': '1', 'chunk': '4', 'entity': 'PROBLEM'}, {'sentence': '1', 'chunk': '5', 'entity': 'PROBLEM'}, {'sentence': '1', 'chunk': '6', 'entity': 'TEST'}]),
#  Row(index='161524', result=['Acute pulmonary embolism', 'artificial neural networks', 'artificial neural networks', 'acute pulmonary embolism', 'pulmonary angiography'], metadata=[{'sentence': '0', 'chunk': '0', 'entity': 'PROBLEM'}, {'sentence': '0', 'chunk': '1', 'entity': 'TREATMENT'}, {'sentence': '1', 'chunk': '2', 'entity': 'TREATMENT'}, {'sentence': '1', 'chunk': '3', 'entity': 'PROBLEM'}, {'sentence': '1', 'chunk': '4', 'entity': 'TEST'}])]

# %%
labelled.toPandas().to_csv('output/labelled.csv')

# %%
from pyspark.sql.functions import split, col

array = result.select(split(col("index"),"::").alias("index_array"),
          col("ner_chunk")) \
    .drop("index")

# %%
array.show(5)
# Out:
# +-----------+--------------------+
# |index_array|           ner_chunk|
# +-----------+--------------------+
# |        [0]|[{chunk, 23, 60, ...|
# |        [2]|[{chunk, 0, 35, S...|
# |        [3]|[{chunk, 14, 34, ...|
# |        [9]|[{chunk, 128, 171...|
# |       [15]|[{chunk, 15, 39, ...|
# +-----------+--------------------+
# only showing top 5 rows

# %%
only_labels = array.select(F.explode(F.arrays_zip('index_array', 'ner_chunk.result', 'ner_chunk.metadata')).alias("cols")) \

only_labels.show(5, truncate = 0)
# Out:
# +---------------------------------------------------------------------------------------------------+
# |cols                                                                                               |
# +---------------------------------------------------------------------------------------------------+
# |{0, a novel artificial intelligence system, {entity -> TREATMENT, sentence -> 0, chunk -> 0}}      |
# |{null, adenoma, {entity -> PROBLEM, sentence -> 0, chunk -> 1}}                                    |
# |{null, a prospective non-randomized comparative study, {entity -> TEST, sentence -> 0, chunk -> 2}}|
# |{null, Adenoma detection rate (ADR, {entity -> PROBLEM, sentence -> 1, chunk -> 3}}                |
# |{null, adenoma miss rate (AMR, {entity -> PROBLEM, sentence -> 1, chunk -> 4}}                     |
# +---------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
labels_tabulated = only_labels.select(F.expr("cols['index_array']").alias("index"),
        F.expr("cols['1']").alias("chunk"),
        F.expr("cols['2']['entity']").alias("ner_label"),
        F.expr("cols['2']['chunk']").alias("rank"))

labels_tabulated.show(20, truncate=0)
# Out:
# +-----+----------------------------------------------+---------+----+
# |index|chunk                                         |ner_label|rank|
# +-----+----------------------------------------------+---------+----+
# |0    |a novel artificial intelligence system        |TREATMENT|0   |
# |null |adenoma                                       |PROBLEM  |1   |
# |null |a prospective non-randomized comparative study|TEST     |2   |
# |null |Adenoma detection rate (ADR                   |PROBLEM  |3   |
# |null |adenoma miss rate (AMR                        |PROBLEM  |4   |
# |null |Artificial intelligence (AI) systems          |TREATMENT|5   |
# |null |endoscopic quality                            |TREATMENT|6   |
# |null |interval cancer                               |PROBLEM  |7   |
# |null |an AI system                                  |PROBLEM  |8   |
# |null |real time colonoscopy                         |TEST     |9   |
# |null |the ADR                                       |PROBLEM  |10  |
# |2    |Synthetic pulmonary perfusion images          |PROBLEM  |0   |
# |null |functional avoidance                          |PROBLEM  |1   |
# |null |synthetic pulmonary perfusion images          |PROBLEM  |2   |
# |null |radiotherapy                                  |TREATMENT|3   |
# |null |lung cancer                                   |PROBLEM  |4   |
# |3    |chemotherapy response                         |TREATMENT|0   |
# |null |breast cancer                                 |PROBLEM  |1   |
# |null |second derivative texture                     |TREATMENT|2   |
# |null |CT images                                     |TEST     |3   |
# +-----+----------------------------------------------+---------+----+
# only showing top 20 rows

# %%
labels_tabulated.toPandas().to_csv('output/labels_tabulated.csv')
